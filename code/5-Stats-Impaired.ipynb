# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
from glob import glob
import pingouin as pg
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

filenames = glob('../models/outputs/CDR_*.csv')
dataframes = [pd.read_csv(f) for f in filenames]

df = pd.concat(dataframes)

df.loc[df['set'].str.contains('Imp'), '2v3'] = 2
df.loc[~df['set'].str.contains('Imp'), '2v3'] = 3

df = df.loc[df['2v3'] == 2]

# %%
df.groupby('set')['Sensitivity','Specificity','PPV','NPV','Accuracy','F1_Score'].mean()
# Out:
#                             Sensitivity  Specificity       PPV       NPV  \
# set
# CDR_Imp_AllFeatures_400        0.939788     0.852558  0.891449  0.917607
# CDR_Imp_B_EFAQ_400             0.930636     0.846899  0.886436  0.905808
# CDR_Imp_Boruta4_400            0.945348     0.841143  0.884318  0.924333
# CDR_Imp_Boruta8_400            0.946939     0.838857  0.883220  0.925625
# CDR_Imp_BorutaSHAP_400         0.947485     0.841260  0.884775  0.926666
# CDR_Imp_UMCN_B_EFAQ_400        0.944788     0.843547  0.885862  0.923357
# CDR_Imp_UMCN_Boruta4-8_400     0.951818     0.845233  0.887716  0.932944
#
#                             Accuracy  F1_Score
# set
# CDR_Imp_AllFeatures_400     0.901514  0.900956
# CDR_Imp_B_EFAQ_400          0.893895  0.893389
# CDR_Imp_Boruta4_400         0.899626  0.898928
# CDR_Imp_Boruta8_400         0.899515  0.898743
# CDR_Imp_BorutaSHAP_400      0.900876  0.900137
# CDR_Imp_UMCN_B_EFAQ_400     0.900366  0.899691
# CDR_Imp_UMCN_Boruta4-8_400  0.905051  0.904343

# %%
df.groupby('set')['Sensitivity','Specificity','PPV','NPV'].var().describe()
# Out:
#        Sensitivity  Specificity       PPV       NPV
# count     7.000000     7.000000  7.000000  7.000000
# mean      0.000347     0.001093  0.000445  0.000560
# std       0.000080     0.000251  0.000108  0.000133
# min       0.000227     0.000795  0.000303  0.000341
# 25%       0.000302     0.000914  0.000375  0.000509
# 50%       0.000343     0.001046  0.000430  0.000568
# 75%       0.000397     0.001261  0.000515  0.000636
# max       0.000462     0.001460  0.000599  0.000722

# %% [markdown]
# # Specificity

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Specificity', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                 W          pval  equal_var
# levene  12.020341  2.257236e-13      False

# %%
display(df.groupby('set')['Specificity'].describe())
aov_sens = pg.anova(data=df, dv='Specificity', between='set')
display(aov_sens)
phoc_sens = pg.pairwise_tukey(data=df, dv='Specificity', between='set')
display(phoc_sens)
# Out:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.852558  0.036722  0.790698  0.821705
# CDR_Imp_B_EFAQ_400          400.0  0.846899  0.028700  0.782946  0.821705
# CDR_Imp_Boruta4_400         400.0  0.841143  0.028189  0.782946  0.813953
# CDR_Imp_Boruta8_400         400.0  0.838857  0.038208  0.759690  0.806202
# CDR_Imp_BorutaSHAP_400      400.0  0.841260  0.034252  0.767442  0.819767
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.843547  0.032338  0.767442  0.821705
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.845233  0.031703  0.759690  0.821705
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.852713  0.883721  0.914729
# CDR_Imp_B_EFAQ_400          0.844961  0.868217  0.914729
# CDR_Imp_Boruta4_400         0.844961  0.868217  0.891473
# CDR_Imp_Boruta8_400         0.844961  0.868217  0.914729
# CDR_Imp_BorutaSHAP_400      0.844961  0.868217  0.906977
# CDR_Imp_UMCN_B_EFAQ_400     0.844961  0.868217  0.914729
# CDR_Imp_UMCN_Boruta4-8_400  0.844961  0.875969  0.899225
#   Source  ddof1  ddof2         F         p-unc       np2
# 0    set      6   2793  7.635345  3.769267e-08  0.016138
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.852558  0.846899
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.852558  0.841143
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.852558  0.838857
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.852558  0.841260
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.852558  0.843547
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.852558  0.845233
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.846899  0.841143
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.846899  0.838857
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.846899  0.841260
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.846899  0.843547
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.846899  0.845233
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.841143  0.838857
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.841143  0.841260
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.841143  0.843547
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.841143  0.845233
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.838857  0.841260
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.838857  0.843547
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.838857  0.845233
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.841260  0.843547
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.841260  0.845233
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.843547  0.845233
#
#         diff        se       tail         T   p-tukey    hedges
# 0   0.005659  0.002338  two-sided  2.420733  0.654246  0.171011
# 1   0.011415  0.002338  two-sided  4.882917  0.001000  0.344950
# 2   0.013702  0.002338  two-sided  5.861158  0.001000  0.414057
# 3   0.011298  0.002338  two-sided  4.833175  0.001000  0.341436
# 4   0.009012  0.002338  two-sided  3.854934  0.654246  0.272329
# 5   0.007326  0.002338  two-sided  3.133688  0.654246  0.221377
# 6   0.005756  0.002338  two-sided  2.462184  0.654246  0.173939
# 7   0.008043  0.002338  two-sided  3.440425  0.654246  0.243046
# 8   0.005640  0.002338  two-sided  2.412443  0.654246  0.170425
# 9   0.003353  0.002338  two-sided  1.434201  0.499998  0.101318
# 10  0.001667  0.002338  two-sided  0.712956  0.900000  0.050366
# 11  0.002287  0.002338  two-sided  0.978241  0.900000  0.069107
# 12 -0.000116  0.002338  two-sided -0.049741  0.900000 -0.003514
# 13 -0.002403  0.002338  two-sided -1.027982  0.900000 -0.072621
# 14 -0.004089  0.002338  two-sided -1.749228  0.499998 -0.123573
# 15 -0.002403  0.002338  two-sided -1.027982  0.900000 -0.072621
# 16 -0.004690  0.002338  two-sided -2.006224  0.412820 -0.141728
# 17 -0.006376  0.002338  two-sided -2.727469  0.654246 -0.192680
# 18 -0.002287  0.002338  two-sided -0.978241  0.900000 -0.069107
# 19 -0.003973  0.002338  two-sided -1.699487  0.499998 -0.120059
# 20 -0.001686  0.002338  two-sided -0.721246  0.900000 -0.050952

# %% [markdown]
# # Impaired Sensitivity

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Sensitivity', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                 W          pval  equal_var
# levene  11.373384  1.349945e-12      False

# %%
display(df.groupby('set')['Sensitivity'].describe())
aov_sens = pg.anova(data=df, dv='Sensitivity', between='set')
display(aov_sens)
phoc_sens = pg.pairwise_tukey(data=df, dv='Sensitivity', between='set')
display(phoc_sens)
# Out:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.939788  0.015062  0.909091  0.927273
# CDR_Imp_B_EFAQ_400          400.0  0.930636  0.019358  0.878788  0.915152
# CDR_Imp_Boruta4_400         400.0  0.945348  0.021490  0.896970  0.927273
# CDR_Imp_Boruta8_400         400.0  0.946939  0.018037  0.903030  0.933333
# CDR_Imp_BorutaSHAP_400      400.0  0.947485  0.016693  0.903030  0.933333
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.944788  0.018523  0.903030  0.927273
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.951818  0.020459  0.903030  0.939394
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.939394  0.951515  0.969697
# CDR_Imp_B_EFAQ_400          0.933333  0.945455  0.969697
# CDR_Imp_Boruta4_400         0.951515  0.963636  0.981818
# CDR_Imp_Boruta8_400         0.945455  0.963636  0.981818
# CDR_Imp_BorutaSHAP_400      0.945455  0.957576  0.981818
# CDR_Imp_UMCN_B_EFAQ_400     0.945455  0.957576  0.981818
# CDR_Imp_UMCN_Boruta4-8_400  0.951515  0.969697  0.987879
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  53.881816  3.979898e-63  0.103742
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.939788  0.930636
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.939788  0.945348
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.939788  0.946939
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.939788  0.947485
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.939788  0.944788
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.939788  0.951818
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.930636  0.945348
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.930636  0.946939
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.930636  0.947485
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.930636  0.944788
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.930636  0.951818
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.945348  0.946939
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.945348  0.947485
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.945348  0.944788
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.945348  0.951818
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.946939  0.947485
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.946939  0.944788
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.946939  0.951818
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.947485  0.944788
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.947485  0.951818
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.944788  0.951818
#
#         diff        se       tail          T   p-tukey    hedges
# 0   0.009152  0.001317  two-sided   6.947530  0.001000  0.490803
# 1  -0.005561  0.001317  two-sided  -4.221430  0.001000 -0.298220
# 2  -0.007152  0.001317  two-sided  -5.429196  0.001000 -0.383541
# 3  -0.007697  0.001317  two-sided  -5.843287  0.001000 -0.412794
# 4  -0.005000  0.001317  two-sided  -3.795836  0.654246 -0.268154
# 5  -0.012030  0.001317  two-sided  -9.133012  0.001000 -0.645194
# 6  -0.014712  0.001317  two-sided -11.168960  0.001000 -0.789022
# 7  -0.016303  0.001317  two-sided -12.376726  0.001000 -0.874344
# 8  -0.016848  0.001317  two-sided -12.790817  0.001000 -0.903597
# 9  -0.014152  0.001317  two-sided -10.743366  0.001000 -0.758957
# 10 -0.021182  0.001317  two-sided -16.080542  0.001000 -1.135997
# 11 -0.001591  0.001317  two-sided  -1.207766  0.499998 -0.085322
# 12 -0.002136  0.001317  two-sided  -1.621857  0.499998 -0.114575
# 13  0.000561  0.001317  two-sided   0.425594  0.900000  0.030066
# 14 -0.006470  0.001317  two-sided  -4.911582  0.001000 -0.346975
# 15 -0.000545  0.001317  two-sided  -0.414091  0.900000 -0.029253
# 16  0.002152  0.001317  two-sided   1.633360  0.499998  0.115387
# 17 -0.004879  0.001317  two-sided  -3.703816  0.654246 -0.261653
# 18  0.002697  0.001317  two-sided   2.047451  0.386255  0.144641
# 19 -0.004333  0.001317  two-sided  -3.289725  0.654246 -0.232400
# 20 -0.007030  0.001317  two-sided  -5.337176  0.001000 -0.377040

# %% [markdown]
# # PPV

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='PPV', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                 W          pval  equal_var
# levene  13.746941  1.883756e-15      False

# %%
print('\n PPV: \n')
display(df.groupby('set')['PPV'].describe())
aov_auc = pg.anova(data=df, dv='PPV', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='PPV', between='set')
display(phoc_auc)
# Out:
#  PPV:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.891449  0.023815  0.854054  0.868571
# CDR_Imp_B_EFAQ_400          400.0  0.886436  0.018779  0.843023  0.870787
# CDR_Imp_Boruta4_400         400.0  0.884318  0.017417  0.849462  0.868852
# CDR_Imp_Boruta8_400         400.0  0.883220  0.024472  0.830601  0.865591
# CDR_Imp_BorutaSHAP_400      400.0  0.884775  0.021509  0.840426  0.869565
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.885862  0.020729  0.839572  0.872222
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.887716  0.019936  0.835979  0.870968
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.892756  0.912281  0.934524
# CDR_Imp_B_EFAQ_400          0.887574  0.898810  0.933333
# CDR_Imp_Boruta4_400         0.885057  0.897727  0.917160
# CDR_Imp_Boruta8_400         0.884393  0.901163  0.935294
# CDR_Imp_BorutaSHAP_400      0.885714  0.901734  0.929412
# CDR_Imp_UMCN_B_EFAQ_400     0.887290  0.899441  0.934524
# CDR_Imp_UMCN_Boruta4-8_400  0.887323  0.904762  0.923529
#   Source  ddof1  ddof2         F         p-unc       np2
# 0    set      6   2793  6.667273  5.104537e-07  0.014121
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.891449  0.886436
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.891449  0.884318
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.891449  0.883220
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.891449  0.884775
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.891449  0.885862
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.891449  0.887716
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.886436  0.884318
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.886436  0.883220
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.886436  0.884775
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.886436  0.885862
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.886436  0.887716
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.884318  0.883220
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.884318  0.884775
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.884318  0.885862
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.884318  0.887716
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.883220  0.884775
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.883220  0.885862
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.883220  0.887716
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.884775  0.885862
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.884775  0.887716
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.885862  0.887716
#
#         diff        se       tail         T   p-tukey    hedges
# 0   0.005013  0.001491  two-sided  3.362403  0.654246  0.237534
# 1   0.007131  0.001491  two-sided  4.783340  0.001000  0.337915
# 2   0.008229  0.001491  two-sided  5.519872  0.001000  0.389947
# 3   0.006674  0.001491  two-sided  4.476772  0.001000  0.316258
# 4   0.005588  0.001491  two-sided  3.747911  0.654246  0.264768
# 5   0.003733  0.001491  two-sided  2.503961  0.654246  0.176890
# 6   0.002118  0.001491  two-sided  1.420937  0.499998  0.100381
# 7   0.003216  0.001491  two-sided  2.157469  0.555282  0.152413
# 8   0.001661  0.001491  two-sided  1.114369  0.900000  0.078724
# 9   0.000575  0.001491  two-sided  0.385508  0.900000  0.027234
# 10 -0.001280  0.001491  two-sided -0.858442  0.900000 -0.060644
# 11  0.001098  0.001491  two-sided  0.736532  0.900000  0.052032
# 12 -0.000457  0.001491  two-sided -0.306568  0.900000 -0.021657
# 13 -0.001544  0.001491  two-sided -1.035430  0.900000 -0.073147
# 14 -0.003398  0.001491  two-sided -2.279380  0.716361 -0.161025
# 15 -0.001555  0.001491  two-sided -1.043100  0.900000 -0.073689
# 16 -0.002642  0.001491  two-sided -1.771961  0.499998 -0.125179
# 17 -0.004496  0.001491  two-sided -3.015911  0.654246 -0.213057
# 18 -0.001087  0.001491  two-sided -0.728861  0.900000 -0.051490
# 19 -0.002941  0.001491  two-sided -1.972812  0.434489 -0.139368
# 20 -0.001855  0.001491  two-sided -1.243950  0.499998 -0.087878

# %% [markdown]
# # NPV

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='NPV', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                 W          pval  equal_var
# levene  12.601439  4.516713e-14      False

# %%
print('\n NPV: \n')
display(df.groupby('set')['NPV'].describe())
aov_auc = pg.anova(data=df, dv='NPV', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='NPV', between='set')
display(phoc_auc)
# Out:
#  NPV:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.917607  0.018462  0.878049  0.904762
# CDR_Imp_B_EFAQ_400          400.0  0.905808  0.023827  0.836066  0.890625
# CDR_Imp_Boruta4_400         400.0  0.924333  0.026874  0.867769  0.904762
# CDR_Imp_Boruta8_400         400.0  0.925625  0.023846  0.872000  0.908257
# CDR_Imp_BorutaSHAP_400      400.0  0.926666  0.021266  0.872000  0.911146
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.923357  0.023788  0.866667  0.902829
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.932944  0.026511  0.875000  0.915966
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.921260  0.933607  0.956522
# CDR_Imp_B_EFAQ_400          0.906878  0.923729  0.956897
# CDR_Imp_Boruta4_400         0.929204  0.945946  0.972477
# CDR_Imp_Boruta8_400         0.919355  0.946547  0.971963
# CDR_Imp_BorutaSHAP_400      0.926829  0.942623  0.974138
# CDR_Imp_UMCN_B_EFAQ_400     0.926230  0.939655  0.973684
# CDR_Imp_UMCN_Boruta4-8_400  0.931624  0.957627  0.981132
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  52.692142  9.405701e-62  0.101685
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.917607  0.905808
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.917607  0.924333
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.917607  0.925625
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.917607  0.926666
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.917607  0.923357
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.917607  0.932944
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.905808  0.924333
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.905808  0.925625
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.905808  0.926666
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.905808  0.923357
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.905808  0.932944
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.924333  0.925625
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.924333  0.926666
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.924333  0.923357
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.924333  0.932944
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.925625  0.926666
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.925625  0.923357
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.925625  0.932944
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.926666  0.923357
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.926666  0.932944
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.923357  0.932944
#
#         diff        se       tail          T   p-tukey    hedges
# 0   0.011798  0.001673  two-sided   7.050464  0.001000  0.498074
# 1  -0.006727  0.001673  two-sided  -4.019884  0.654246 -0.283981
# 2  -0.008019  0.001673  two-sided  -4.791934  0.001000 -0.338522
# 3  -0.009060  0.001673  two-sided  -5.413840  0.001000 -0.382456
# 4  -0.005751  0.001673  two-sided  -3.436449  0.654246 -0.242765
# 5  -0.015337  0.001673  two-sided  -9.165226  0.001000 -0.647470
# 6  -0.018525  0.001673  two-sided -11.070348  0.001000 -0.782056
# 7  -0.019817  0.001673  two-sided -11.842399  0.001000 -0.836597
# 8  -0.020858  0.001673  two-sided -12.464305  0.001000 -0.880531
# 9  -0.017549  0.001673  two-sided -10.486913  0.001000 -0.740840
# 10 -0.027135  0.001673  two-sided -16.215690  0.001000 -1.145544
# 11 -0.001292  0.001673  two-sided  -0.772051  0.900000 -0.054541
# 12 -0.002333  0.001673  two-sided  -1.393957  0.499998 -0.098475
# 13  0.000976  0.001673  two-sided   0.583435  0.900000  0.041216
# 14 -0.008610  0.001673  two-sided  -5.145342  0.001000 -0.363489
# 15 -0.001041  0.001673  two-sided  -0.621906  0.900000 -0.043934
# 16  0.002268  0.001673  two-sided   1.355485  0.499998  0.095757
# 17 -0.007318  0.001673  two-sided  -4.373291  0.001000 -0.308948
# 18  0.003309  0.001673  two-sided   1.977391  0.431521  0.139691
# 19 -0.006278  0.001673  two-sided  -3.751386  0.654246 -0.265014
# 20 -0.009587  0.001673  two-sided  -5.728777  0.001000 -0.404705

# %% [markdown]
# # Accuracy

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Accuracy', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  9.384399  3.215592e-10      False

# %%
print('\n Accuracy: \n')
display(df.groupby('set')['Accuracy'].describe())
aov_auc = pg.anova(data=df, dv='Accuracy', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='Accuracy', between='set')
display(phoc_auc)
# Out:
#  Accuracy:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.901514  0.016154  0.874150  0.887755
# CDR_Imp_B_EFAQ_400          400.0  0.893895  0.015613  0.840136  0.884354
# CDR_Imp_Boruta4_400         400.0  0.899626  0.013737  0.863946  0.891156
# CDR_Imp_Boruta8_400         400.0  0.899515  0.019577  0.850340  0.887755
# CDR_Imp_BorutaSHAP_400      400.0  0.900876  0.015574  0.863946  0.887755
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.900366  0.016713  0.860544  0.887755
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.905051  0.015875  0.867347  0.894558
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.901361  0.914966  0.935374
# CDR_Imp_B_EFAQ_400          0.894558  0.904762  0.931973
# CDR_Imp_Boruta4_400         0.897959  0.908163  0.928571
# CDR_Imp_Boruta8_400         0.897959  0.911565  0.942177
# CDR_Imp_BorutaSHAP_400      0.897959  0.911565  0.935374
# CDR_Imp_UMCN_B_EFAQ_400     0.901361  0.911565  0.942177
# CDR_Imp_UMCN_Boruta4-8_400  0.904762  0.914966  0.938776
#   Source  ddof1  ddof2          F         p-unc      np2
# 0    set      6   2793  16.708385  5.002606e-19  0.03465
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.901514  0.893895
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.901514  0.899626
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.901514  0.899515
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.901514  0.900876
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.901514  0.900366
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.901514  0.905051
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.893895  0.899626
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.893895  0.899515
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.893895  0.900876
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.893895  0.900366
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.893895  0.905051
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.899626  0.899515
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.899626  0.900876
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.899626  0.900366
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.899626  0.905051
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.899515  0.900876
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.899515  0.900366
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.899515  0.905051
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.900876  0.900366
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.900876  0.905051
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.900366  0.905051
#
#         diff       se       tail         T   p-tukey    hedges
# 0   0.007619  0.00115  two-sided  6.627048  0.001000  0.468163
# 1   0.001888  0.00115  two-sided  1.641970  0.499998  0.115996
# 2   0.001998  0.00115  two-sided  1.738121  0.499998  0.122788
# 3   0.000638  0.00115  two-sided  0.554719  0.900000  0.039188
# 4   0.001148  0.00115  two-sided  0.998495  0.900000  0.070538
# 5  -0.003537  0.00115  two-sided -3.076844  0.654246 -0.217361
# 6  -0.005731  0.00115  two-sided -4.985079  0.001000 -0.352167
# 7  -0.005621  0.00115  two-sided -4.888927  0.001000 -0.345374
# 8  -0.006981  0.00115  two-sided -6.072329  0.001000 -0.428975
# 9  -0.006471  0.00115  two-sided -5.628553  0.001000 -0.397625
# 10 -0.011156  0.00115  two-sided -9.703892  0.001000 -0.685524
# 11  0.000111  0.00115  two-sided  0.096151  0.900000  0.006793
# 12 -0.001250  0.00115  two-sided -1.087250  0.900000 -0.076808
# 13 -0.000740  0.00115  two-sided -0.643475  0.900000 -0.045458
# 14 -0.005425  0.00115  two-sided -4.718813  0.001000 -0.333357
# 15 -0.001361  0.00115  two-sided -1.183402  0.900000 -0.083600
# 16 -0.000850  0.00115  two-sided -0.739626  0.900000 -0.052250
# 17 -0.005536  0.00115  two-sided -4.814965  0.001000 -0.340149
# 18  0.000510  0.00115  two-sided  0.443776  0.900000  0.031350
# 19 -0.004175  0.00115  two-sided -3.631563  0.654246 -0.256549
# 20 -0.004685  0.00115  two-sided -4.075339  0.001000 -0.287899

# %% [markdown]
# # F1

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='F1_Score', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  9.803123  1.019918e-10      False

# %%
print('\n F1_Score: \n')
display(df.groupby('set')['F1_Score'].describe())
aov_auc = pg.anova(data=df, dv='F1_Score', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='F1_Score', between='set')
display(phoc_auc)
# Out:
#  F1_Score:
#                             count      mean       std       min       25%  \
# set
# CDR_Imp_AllFeatures_400     400.0  0.900956  0.016453  0.873546  0.887356
# CDR_Imp_B_EFAQ_400          400.0  0.893389  0.015731  0.839567  0.883205
# CDR_Imp_Boruta4_400         400.0  0.898928  0.013838  0.863379  0.890484
# CDR_Imp_Boruta8_400         400.0  0.898743  0.019935  0.848598  0.887217
# CDR_Imp_BorutaSHAP_400      400.0  0.900137  0.015891  0.862362  0.887600
# CDR_Imp_UMCN_B_EFAQ_400     400.0  0.899691  0.016951  0.859487  0.887066
# CDR_Imp_UMCN_Boruta4-8_400  400.0  0.904343  0.016085  0.866533  0.894052
#
#                                  50%       75%       max
# set
# CDR_Imp_AllFeatures_400     0.900887  0.914760  0.935285
# CDR_Imp_B_EFAQ_400          0.894052  0.904110  0.931844
# CDR_Imp_Boruta4_400         0.897108  0.908037  0.928133
# CDR_Imp_Boruta8_400         0.897711  0.910721  0.942037
# CDR_Imp_BorutaSHAP_400      0.897868  0.910959  0.935218
# CDR_Imp_UMCN_B_EFAQ_400     0.900379  0.911082  0.941971
# CDR_Imp_UMCN_Boruta4-8_400  0.904110  0.914760  0.938442
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  15.734455  7.517015e-18  0.032696
#                           A                           B   mean(A)   mean(B)  \
# 0   CDR_Imp_AllFeatures_400          CDR_Imp_B_EFAQ_400  0.900956  0.893389
# 1   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta4_400  0.900956  0.898928
# 2   CDR_Imp_AllFeatures_400         CDR_Imp_Boruta8_400  0.900956  0.898743
# 3   CDR_Imp_AllFeatures_400      CDR_Imp_BorutaSHAP_400  0.900956  0.900137
# 4   CDR_Imp_AllFeatures_400     CDR_Imp_UMCN_B_EFAQ_400  0.900956  0.899691
# 5   CDR_Imp_AllFeatures_400  CDR_Imp_UMCN_Boruta4-8_400  0.900956  0.904343
# 6        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta4_400  0.893389  0.898928
# 7        CDR_Imp_B_EFAQ_400         CDR_Imp_Boruta8_400  0.893389  0.898743
# 8        CDR_Imp_B_EFAQ_400      CDR_Imp_BorutaSHAP_400  0.893389  0.900137
# 9        CDR_Imp_B_EFAQ_400     CDR_Imp_UMCN_B_EFAQ_400  0.893389  0.899691
# 10       CDR_Imp_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.893389  0.904343
# 11      CDR_Imp_Boruta4_400         CDR_Imp_Boruta8_400  0.898928  0.898743
# 12      CDR_Imp_Boruta4_400      CDR_Imp_BorutaSHAP_400  0.898928  0.900137
# 13      CDR_Imp_Boruta4_400     CDR_Imp_UMCN_B_EFAQ_400  0.898928  0.899691
# 14      CDR_Imp_Boruta4_400  CDR_Imp_UMCN_Boruta4-8_400  0.898928  0.904343
# 15      CDR_Imp_Boruta8_400      CDR_Imp_BorutaSHAP_400  0.898743  0.900137
# 16      CDR_Imp_Boruta8_400     CDR_Imp_UMCN_B_EFAQ_400  0.898743  0.899691
# 17      CDR_Imp_Boruta8_400  CDR_Imp_UMCN_Boruta4-8_400  0.898743  0.904343
# 18   CDR_Imp_BorutaSHAP_400     CDR_Imp_UMCN_B_EFAQ_400  0.900137  0.899691
# 19   CDR_Imp_BorutaSHAP_400  CDR_Imp_UMCN_Boruta4-8_400  0.900137  0.904343
# 20  CDR_Imp_UMCN_B_EFAQ_400  CDR_Imp_UMCN_Boruta4-8_400  0.899691  0.904343
#
#         diff        se       tail         T   p-tukey    hedges
# 0   0.007567  0.001167  two-sided  6.485752  0.001000  0.458181
# 1   0.002028  0.001167  two-sided  1.737984  0.499998  0.122778
# 2   0.002213  0.001167  two-sided  1.896949  0.483103  0.134008
# 3   0.000818  0.001167  two-sided  0.701519  0.900000  0.049558
# 4   0.001265  0.001167  two-sided  1.083841  0.900000  0.076567
# 5  -0.003388  0.001167  two-sided -2.903525  0.654246 -0.205117
# 6  -0.005539  0.001167  two-sided -4.747768  0.001000 -0.335402
# 7  -0.005354  0.001167  two-sided -4.588803  0.001000 -0.324172
# 8  -0.006748  0.001167  two-sided -5.784233  0.001000 -0.408622
# 9  -0.006302  0.001167  two-sided -5.401911  0.001000 -0.381614
# 10 -0.010954  0.001167  two-sided -9.389277  0.001000 -0.663298
# 11  0.000185  0.001167  two-sided  0.158965  0.900000  0.011230
# 12 -0.001209  0.001167  two-sided -1.036464  0.900000 -0.073220
# 13 -0.000763  0.001167  two-sided -0.654143  0.900000 -0.046211
# 14 -0.005415  0.001167  two-sided -4.641508  0.001000 -0.327896
# 15 -0.001395  0.001167  two-sided -1.195429  0.499998 -0.084450
# 16 -0.000949  0.001167  two-sided -0.813108  0.900000 -0.057441
# 17 -0.005601  0.001167  two-sided -4.800473  0.001000 -0.339126
# 18  0.000446  0.001167  two-sided  0.382321  0.900000  0.027009
# 19 -0.004206  0.001167  two-sided -3.605044  0.654246 -0.254675
# 20 -0.004652  0.001167  two-sided -3.987366  0.654246 -0.281684
