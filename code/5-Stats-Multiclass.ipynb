# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
from glob import glob
import pingouin as pg
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

filenames = glob('../models/outputs/CDR_*.csv')
dataframes = [pd.read_csv(f) for f in filenames]

df = pd.concat(dataframes)

df.loc[df['set'].str.contains('Imp'), '2v3'] = 2
df.loc[~df['set'].str.contains('Imp'), '2v3'] = 3

df = df.loc[df['2v3'] == 3]

# %%
df.groupby('set')['Sensitivity','Specificity','PPV','NPV','Accuracy','F1_Score'].mean()
# Out:
#                               Sensitivity  Specificity       PPV       NPV  \
# set
# CDR_MultiC_AllFeatures_400       0.926402     0.865673  0.897413  0.903962
# CDR_MultiC_BorutaECOGFAQ_400     0.915534     0.866231  0.896592  0.890950
# CDR_MultiC_BorutaSHAP_400        0.923369     0.864058  0.895915  0.899851
# CDR_UMCN_AllFeatures_400         0.915046     0.875327  0.902901  0.892005
# CDR_UMCN_Boruta4_400             0.928460     0.851173  0.887529  0.904647
# CDR_UMCN_BorutaECOGFAQ_400       0.919665     0.843673  0.881547  0.893355
# CDR_UMCN_BorutaSHAP_400          0.909634     0.871250  0.899423  0.884998
#
#                               Accuracy  F1_Score
# set
# CDR_MultiC_AllFeatures_400    0.899549  0.899253
# CDR_MultiC_BorutaECOGFAQ_400  0.893733  0.893528
# CDR_MultiC_BorutaSHAP_400     0.897143  0.896861
# CDR_UMCN_AllFeatures_400      0.897483  0.897351
# CDR_UMCN_Boruta4_400          0.894286  0.893863
# CDR_UMCN_BorutaECOGFAQ_400    0.886063  0.885637
# CDR_UMCN_BorutaSHAP_400       0.892662  0.892546

# %%
df.groupby('set')['Sensitivity','Specificity','PPV','NPV'].var().describe()
# Out:
#        Sensitivity  Specificity       PPV       NPV
# count     7.000000     7.000000  7.000000  7.000000
# mean      0.000459     0.000703  0.000328  0.000617
# std       0.000108     0.000127  0.000057  0.000116
# min       0.000321     0.000533  0.000242  0.000442
# 25%       0.000394     0.000625  0.000297  0.000553
# 50%       0.000440     0.000695  0.000328  0.000638
# 75%       0.000509     0.000777  0.000359  0.000676
# max       0.000649     0.000889  0.000410  0.000781

# %% [markdown]
# # Specificity

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Specificity', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  8.154366  9.227356e-09      False

# %%
display(df.groupby('set')['Specificity'].describe())
aov_sens = pg.anova(data=df, dv='Specificity', between='set')
display(aov_sens)
phoc_sens = pg.pairwise_tukey(data=df, dv='Specificity', between='set')
display(phoc_sens)
# Out:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.865673  0.029818  0.800000  0.838462
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.866231  0.027773  0.792308  0.853846
# CDR_MultiC_BorutaSHAP_400     400.0  0.864058  0.027962  0.792308  0.844231
# CDR_UMCN_AllFeatures_400      400.0  0.875327  0.023086  0.823077  0.861538
# CDR_UMCN_Boruta4_400          400.0  0.851173  0.026364  0.784615  0.838462
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.843673  0.026360  0.792308  0.823077
# CDR_UMCN_BorutaSHAP_400       400.0  0.871250  0.023549  0.823077  0.846154
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.869231  0.892308  0.930769
# CDR_MultiC_BorutaECOGFAQ_400  0.873077  0.884615  0.915385
# CDR_MultiC_BorutaSHAP_400     0.869231  0.884615  0.915385
# CDR_UMCN_AllFeatures_400      0.876923  0.892308  0.923077
# CDR_UMCN_Boruta4_400          0.846154  0.869231  0.900000
# CDR_UMCN_BorutaECOGFAQ_400    0.846154  0.861538  0.900000
# CDR_UMCN_BorutaSHAP_400       0.876923  0.892308  0.923077
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  71.166907  9.041948e-83  0.132609
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.865673
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.865673
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.865673
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.865673
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.865673
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.865673
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.866231
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.866231
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.866231
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.866231
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.866231
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.864058
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.864058
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.864058
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.864058
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.875327
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.875327
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.875327
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.851173
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.851173
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.843673
#
#      mean(B)      diff        se       tail          T   p-tukey    hedges
# 0   0.866231 -0.000558  0.001875  two-sided  -0.297502  0.900000 -0.021017
# 1   0.864058  0.001615  0.001875  two-sided   0.861729  0.900000  0.060876
# 2   0.875327 -0.009654  0.001875  two-sided  -5.149858  0.001000 -0.363808
# 3   0.851173  0.014500  0.001875  two-sided   7.735045  0.001000  0.546436
# 4   0.843673  0.022000  0.001875  two-sided  11.735931  0.001000  0.829075
# 5   0.871250 -0.005577  0.001875  two-sided  -2.975017  0.654246 -0.210168
# 6   0.864058  0.002173  0.001875  two-sided   1.159231  0.900000  0.081893
# 7   0.875327 -0.009096  0.001875  two-sided  -4.852356  0.001000 -0.342791
# 8   0.851173  0.015058  0.001875  two-sided   8.032547  0.001000  0.567453
# 9   0.843673  0.022558  0.001875  two-sided  12.033433  0.001000  0.850092
# 10  0.871250 -0.005019  0.001875  two-sided  -2.677516  0.654246 -0.189151
# 11  0.875327 -0.011269  0.001875  two-sided  -6.011587  0.001000 -0.424684
# 12  0.851173  0.012885  0.001875  two-sided   6.873316  0.001000  0.485560
# 13  0.843673  0.020385  0.001875  two-sided  10.874202  0.001000  0.768199
# 14  0.871250 -0.007192  0.001875  two-sided  -3.836747  0.654246 -0.271044
# 15  0.851173  0.024154  0.001875  two-sided  12.884903  0.001000  0.910244
# 16  0.843673  0.031654  0.001875  two-sided  16.885789  0.001000  1.192883
# 17  0.871250  0.004077  0.001875  two-sided   2.174840  0.559686  0.153640
# 18  0.843673  0.007500  0.001875  two-sided   4.000886  0.654246  0.282639
# 19  0.871250 -0.020077  0.001875  two-sided -10.710063  0.001000 -0.756604
# 20  0.871250 -0.027577  0.001875  two-sided -14.710948  0.001000 -1.039243

# %% [markdown]
# # Impaired Sensitivity

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Sensitivity', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#               W      pval  equal_var
# levene  4.52555  0.000142      False

# %%
display(df.groupby('set')['Sensitivity'].describe())
aov_sens = pg.anova(data=df, dv='Sensitivity', between='set')
display(aov_sens)
phoc_sens = pg.pairwise_tukey(data=df, dv='Sensitivity', between='set')
display(phoc_sens)
# Out:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.926402  0.022659  0.871951  0.914634
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.915534  0.019225  0.871951  0.902439
# CDR_MultiC_BorutaSHAP_400     400.0  0.923369  0.017910  0.890244  0.908537
# CDR_UMCN_AllFeatures_400      400.0  0.915046  0.025480  0.859756  0.902439
# CDR_UMCN_Boruta4_400          400.0  0.928460  0.020469  0.878049  0.914634
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.919665  0.020980  0.878049  0.902439
# CDR_UMCN_BorutaSHAP_400       400.0  0.909634  0.022442  0.853659  0.896341
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.926829  0.939024  0.969512
# CDR_MultiC_BorutaECOGFAQ_400  0.914634  0.932927  0.945122
# CDR_MultiC_BorutaSHAP_400     0.920732  0.939024  0.963415
# CDR_UMCN_AllFeatures_400      0.908537  0.939024  0.969512
# CDR_UMCN_Boruta4_400          0.926829  0.945122  0.969512
# CDR_UMCN_BorutaECOGFAQ_400    0.914634  0.932927  0.963415
# CDR_UMCN_BorutaSHAP_400       0.908537  0.920732  0.951220
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  39.974117  6.724758e-47  0.079082
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.926402
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.926402
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.926402
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.926402
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.926402
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.926402
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.915534
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.915534
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.915534
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.915534
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.915534
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.923369
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.923369
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.923369
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.923369
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.915046
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.915046
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.915046
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.928460
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.928460
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.919665
#
#      mean(B)      diff        se       tail          T   p-tukey    hedges
# 0   0.915534  0.010869  0.001516  two-sided   7.171370  0.001000  0.506616
# 1   0.923369  0.003034  0.001516  two-sided   2.001546  0.415851  0.141398
# 2   0.915046  0.011357  0.001516  two-sided   7.493226  0.001000  0.529353
# 3   0.928460 -0.002058  0.001516  two-sided  -1.357833  0.499998 -0.095923
# 4   0.919665  0.006738  0.001516  two-sided   4.445646  0.001000  0.314059
# 5   0.909634  0.016768  0.001516  two-sided  11.063824  0.001000  0.781595
# 6   0.923369 -0.007835  0.001516  two-sided  -5.169823  0.001000 -0.365218
# 7   0.915046  0.000488  0.001516  two-sided   0.321857  0.900000  0.022737
# 8   0.928460 -0.012927  0.001516  two-sided  -8.529203  0.001000 -0.602539
# 9   0.919665 -0.004131  0.001516  two-sided  -2.725724  0.654246 -0.192557
# 10  0.909634  0.005899  0.001516  two-sided   3.892455  0.654246  0.274979
# 11  0.915046  0.008323  0.001516  two-sided   5.491680  0.001000  0.387955
# 12  0.928460 -0.005091  0.001516  two-sided  -3.359379  0.654246 -0.237321
# 13  0.919665  0.003704  0.001516  two-sided   2.444099  0.654246  0.172661
# 14  0.909634  0.013735  0.001516  two-sided   9.062278  0.001000  0.640197
# 15  0.928460 -0.013415  0.001516  two-sided  -8.851059  0.001000 -0.625276
# 16  0.919665 -0.004619  0.001516  two-sided  -3.047581  0.654246 -0.215294
# 17  0.909634  0.005412  0.001516  two-sided   3.570598  0.654246  0.252242
# 18  0.919665  0.008796  0.001516  two-sided   5.803479  0.001000  0.409982
# 19  0.909634  0.018826  0.001516  two-sided  12.421657  0.001000  0.877518
# 20  0.909634  0.010030  0.001516  two-sided   6.618179  0.001000  0.467536

# %% [markdown]
# # PPV

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='PPV', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  7.290816  9.557997e-08      False

# %%
print('\n PPV: \n')
display(df.groupby('set')['PPV'].describe())
aov_auc = pg.anova(data=df, dv='PPV', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='PPV', between='set')
display(phoc_auc)
# Out:
#  PPV:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.897413  0.020258  0.851429  0.880682
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.896592  0.018927  0.845714  0.886905
# CDR_MultiC_BorutaSHAP_400     400.0  0.895915  0.018953  0.846591  0.880682
# CDR_UMCN_AllFeatures_400      400.0  0.902901  0.015570  0.869318  0.892216
# CDR_UMCN_Boruta4_400          400.0  0.887529  0.018120  0.842697  0.876471
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.881547  0.017999  0.845714  0.867052
# CDR_UMCN_BorutaSHAP_400       400.0  0.899423  0.016438  0.863095  0.883721
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.898810  0.914110  0.943750
# CDR_MultiC_BorutaECOGFAQ_400  0.900000  0.910714  0.930380
# CDR_MultiC_BorutaSHAP_400     0.901163  0.911243  0.930380
# CDR_UMCN_AllFeatures_400      0.903903  0.913872  0.936709
# CDR_UMCN_Boruta4_400          0.886955  0.900000  0.923077
# CDR_UMCN_BorutaECOGFAQ_400    0.880240  0.895438  0.921212
# CDR_UMCN_BorutaSHAP_400       0.902140  0.911243  0.936709
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  66.364064  2.269052e-77  0.124776
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.897413
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.897413
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.897413
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.897413
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.897413
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.897413
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.896592
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.896592
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.896592
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.896592
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.896592
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.895915
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.895915
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.895915
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.895915
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.902901
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.902901
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.902901
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.887529
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.887529
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.881547
#
#      mean(B)      diff       se       tail          T   p-tukey    hedges
# 0   0.896592  0.000820  0.00128  two-sided   0.640846  0.900000  0.045272
# 1   0.895915  0.001497  0.00128  two-sided   1.169880  0.900000  0.082645
# 2   0.902901 -0.005488  0.00128  two-sided  -4.288783  0.001000 -0.302978
# 3   0.887529  0.009884  0.00128  two-sided   7.723125  0.001000  0.545594
# 4   0.881547  0.015866  0.00128  two-sided  12.397683  0.001000  0.875824
# 5   0.899423 -0.002011  0.00128  two-sided  -1.571279  0.499998 -0.111002
# 6   0.895915  0.000677  0.00128  two-sided   0.529033  0.900000  0.037373
# 7   0.902901 -0.006309  0.00128  two-sided  -4.929630  0.001000 -0.348250
# 8   0.887529  0.009063  0.00128  two-sided   7.082278  0.001000  0.500322
# 9   0.881547  0.015046  0.00128  two-sided  11.756836  0.001000  0.830552
# 10  0.899423 -0.002831  0.00128  two-sided  -2.212125  0.569936 -0.156274
# 11  0.902901 -0.006986  0.00128  two-sided  -5.458663  0.001000 -0.385623
# 12  0.887529  0.008386  0.00128  two-sided   6.553245  0.001000  0.462949
# 13  0.881547  0.014369  0.00128  two-sided  11.227803  0.001000  0.793179
# 14  0.899423 -0.003508  0.00128  two-sided  -2.741158  0.654246 -0.193647
# 15  0.887529  0.015372  0.00128  two-sided  12.011908  0.001000  0.848572
# 16  0.881547  0.021354  0.00128  two-sided  16.686466  0.001000  1.178802
# 17  0.899423  0.003478  0.00128  two-sided   2.717505  0.654246  0.191976
# 18  0.881547  0.005982  0.00128  two-sided   4.674558  0.001000  0.330230
# 19  0.899423 -0.011894  0.00128  two-sided  -9.294404  0.001000 -0.656596
# 20  0.899423 -0.017877  0.00128  two-sided -13.968962  0.001000 -0.986826

# %% [markdown]
# # NPV

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='NPV', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W      pval  equal_var
# levene  3.604519  0.001455      False

# %%
print('\n NPV: \n')
display(df.groupby('set')['NPV'].describe())
aov_auc = pg.anova(data=df, dv='NPV', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='NPV', between='set')
display(phoc_auc)
# Out:
#  NPV:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.903962  0.026374  0.846715  0.886317
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.890950  0.022196  0.843284  0.871803
# CDR_MultiC_BorutaSHAP_400     400.0  0.899851  0.021016  0.864662  0.879699
# CDR_UMCN_AllFeatures_400      400.0  0.892005  0.027947  0.835714  0.877628
# CDR_UMCN_Boruta4_400          400.0  0.904647  0.025259  0.850746  0.881890
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.893355  0.025640  0.842520  0.872982
# CDR_UMCN_BorutaSHAP_400       400.0  0.884998  0.024766  0.827338  0.872000
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.902256  0.920635  0.957627
# CDR_MultiC_BorutaECOGFAQ_400  0.888444  0.907563  0.928571
# CDR_MultiC_BorutaSHAP_400     0.898438  0.917355  0.948718
# CDR_UMCN_AllFeatures_400      0.887218  0.915254  0.958333
# CDR_UMCN_Boruta4_400          0.903226  0.924370  0.956522
# CDR_UMCN_BorutaECOGFAQ_400    0.890625  0.912175  0.946903
# CDR_UMCN_BorutaSHAP_400       0.885246  0.899419  0.935484
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  34.762814  1.003838e-40  0.069489
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.903962
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.903962
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.903962
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.903962
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.903962
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.903962
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.890950
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.890950
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.890950
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.890950
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.890950
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.899851
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.899851
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.899851
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.899851
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.892005
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.892005
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.892005
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.904647
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.904647
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.893355
#
#      mean(B)      diff        se       tail          T   p-tukey    hedges
# 0   0.890950  0.013012  0.001757  two-sided   7.407715  0.001000  0.523312
# 1   0.899851  0.004111  0.001757  two-sided   2.340543  0.681625  0.165346
# 2   0.892005  0.011957  0.001757  two-sided   6.807122  0.001000  0.480884
# 3   0.904647 -0.000685  0.001757  two-sided  -0.390046  0.900000 -0.027554
# 4   0.893355  0.010607  0.001757  two-sided   6.038395  0.001000  0.426578
# 5   0.884998  0.018964  0.001757  two-sided  10.796005  0.001000  0.762675
# 6   0.899851 -0.008901  0.001757  two-sided  -5.067172  0.001000 -0.357966
# 7   0.892005 -0.001055  0.001757  two-sided  -0.600593  0.900000 -0.042428
# 8   0.904647 -0.013697  0.001757  two-sided  -7.797761  0.001000 -0.550867
# 9   0.893355 -0.002405  0.001757  two-sided  -1.369320  0.499998 -0.096734
# 10  0.884998  0.005952  0.001757  two-sided   3.388289  0.654246  0.239363
# 11  0.892005  0.007846  0.001757  two-sided   4.466580  0.001000  0.315538
# 12  0.904647 -0.004796  0.001757  two-sided  -2.730589  0.654246 -0.192900
# 13  0.893355  0.006495  0.001757  two-sided   3.697853  0.654246  0.261232
# 14  0.884998  0.014853  0.001757  two-sided   8.455462  0.001000  0.597329
# 15  0.904647 -0.012642  0.001757  two-sided  -7.197168  0.001000 -0.508438
# 16  0.893355 -0.001350  0.001757  two-sided  -0.768727  0.900000 -0.054306
# 17  0.884998  0.007007  0.001757  two-sided   3.988882  0.654246  0.281791
# 18  0.893355  0.011292  0.001757  two-sided   6.428441  0.001000  0.454132
# 19  0.884998  0.019649  0.001757  two-sided  11.186050  0.001000  0.790230
# 20  0.884998  0.008357  0.001757  two-sided   4.757609  0.001000  0.336097

# %% [markdown]
# # Accuracy

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='Accuracy', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  7.799306  2.418126e-08      False

# %%
print('\n Accuracy: \n')
display(df.groupby('set')['Accuracy'].describe())
aov_auc = pg.anova(data=df, dv='Accuracy', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='Accuracy', between='set')
display(phoc_auc)
# Out:
#  Accuracy:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.899549  0.016458  0.860544  0.887755
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.893733  0.015829  0.853741  0.884354
# CDR_MultiC_BorutaSHAP_400     400.0  0.897143  0.014818  0.857143  0.887755
# CDR_UMCN_AllFeatures_400      400.0  0.897483  0.014081  0.870748  0.887755
# CDR_UMCN_Boruta4_400          400.0  0.894286  0.017428  0.857143  0.880952
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.886063  0.016931  0.853741  0.873299
# CDR_UMCN_BorutaSHAP_400       400.0  0.892662  0.015227  0.857143  0.880952
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.897959  0.911565  0.935374
# CDR_MultiC_BorutaECOGFAQ_400  0.887755  0.908163  0.925170
# CDR_MultiC_BorutaSHAP_400     0.897959  0.911565  0.921769
# CDR_UMCN_AllFeatures_400      0.894558  0.908163  0.931973
# CDR_UMCN_Boruta4_400          0.891156  0.911565  0.928571
# CDR_UMCN_BorutaECOGFAQ_400    0.884354  0.901361  0.925170
# CDR_UMCN_BorutaSHAP_400       0.891156  0.904762  0.928571
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  30.870523  4.401669e-36  0.062192
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.899549
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.899549
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.899549
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.899549
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.899549
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.899549
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.893733
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.893733
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.893733
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.893733
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.893733
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.897143
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.897143
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.897143
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.897143
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.897483
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.897483
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.897483
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.894286
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.894286
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.886063
#
#      mean(B)      diff        se       tail          T   p-tukey    hedges
# 0   0.893733  0.005816  0.001122  two-sided   5.185197  0.001000  0.366304
# 1   0.897143  0.002406  0.001122  two-sided   2.145337  0.552321  0.151556
# 2   0.897483  0.002066  0.001122  two-sided   1.842109  0.499998  0.130134
# 3   0.894286  0.005264  0.001122  two-sided   4.692452  0.001000  0.331494
# 4   0.886063  0.013486  0.001122  two-sided  12.022986  0.001000  0.849354
# 5   0.892662  0.006888  0.001122  two-sided   6.140365  0.001000  0.433781
# 6   0.897143 -0.003410  0.001122  two-sided  -3.039860  0.654246 -0.214748
# 7   0.897483 -0.003750  0.001122  two-sided  -3.343087  0.654246 -0.236170
# 8   0.894286 -0.000553  0.001122  two-sided  -0.492745  0.900000 -0.034810
# 9   0.886063  0.007670  0.001122  two-sided   6.837789  0.001000  0.483050
# 10  0.892662  0.001071  0.001122  two-sided   0.955168  0.900000  0.067477
# 11  0.897483 -0.000340  0.001122  two-sided  -0.303228  0.900000 -0.021421
# 12  0.894286  0.002857  0.001122  two-sided   2.547114  0.654246  0.179939
# 13  0.886063  0.011080  0.001122  two-sided   9.877648  0.001000  0.697799
# 14  0.892662  0.004481  0.001122  two-sided   3.995027  0.654246  0.282226
# 15  0.894286  0.003197  0.001122  two-sided   2.850342  0.654246  0.201360
# 16  0.886063  0.011420  0.001122  two-sided  10.180876  0.001000  0.719220
# 17  0.892662  0.004821  0.001122  two-sided   4.298255  0.001000  0.303647
# 18  0.886063  0.008223  0.001122  two-sided   7.330534  0.001000  0.517860
# 19  0.892662  0.001624  0.001122  two-sided   1.447913  0.499998  0.102287
# 20  0.892662 -0.006599  0.001122  two-sided  -5.882621  0.001000 -0.415573

# %% [markdown]
# # F1

# %% [markdown]
# ### Levene's test:

# %%
aov_levene = pg.homoscedasticity(data=df, dv='F1_Score', group='set', method='levene', alpha=0.05)
display(aov_levene)
# Out:
#                W          pval  equal_var
# levene  7.875605  1.966408e-08      False

# %%
print('\n F1_Score: \n')
display(df.groupby('set')['F1_Score'].describe())
aov_auc = pg.anova(data=df, dv='F1_Score', between='set')
display(aov_auc)
phoc_auc = pg.pairwise_tukey(data=df, dv='F1_Score', between='set')
display(phoc_auc)
# Out:
#  F1_Score:
#                               count      mean       std       min       25%  \
# set
# CDR_MultiC_AllFeatures_400    400.0  0.899253  0.016540  0.859726  0.887097
# CDR_MultiC_BorutaECOGFAQ_400  400.0  0.893528  0.015928  0.852884  0.884147
# CDR_MultiC_BorutaSHAP_400     400.0  0.896861  0.014942  0.856208  0.887709
# CDR_UMCN_AllFeatures_400      400.0  0.897351  0.014027  0.870383  0.887799
# CDR_UMCN_Boruta4_400          400.0  0.893863  0.017511  0.856002  0.880647
# CDR_UMCN_BorutaECOGFAQ_400    400.0  0.885637  0.016987  0.852884  0.872446
# CDR_UMCN_BorutaSHAP_400       400.0  0.892546  0.015216  0.856887  0.880549
#
#                                    50%       75%       max
# set
# CDR_MultiC_AllFeatures_400    0.897491  0.911645  0.935155
# CDR_MultiC_BorutaECOGFAQ_400  0.887877  0.908064  0.925036
# CDR_MultiC_BorutaSHAP_400     0.897873  0.911214  0.921737
# CDR_UMCN_AllFeatures_400      0.894599  0.907952  0.931703
# CDR_UMCN_Boruta4_400          0.890590  0.910858  0.928407
# CDR_UMCN_BorutaECOGFAQ_400    0.884027  0.901027  0.924873
# CDR_UMCN_BorutaSHAP_400       0.891309  0.904896  0.928478
#   Source  ddof1  ddof2          F         p-unc       np2
# 0    set      6   2793  31.342262  1.201439e-36  0.063083
#                                A                             B   mean(A)  \
# 0     CDR_MultiC_AllFeatures_400  CDR_MultiC_BorutaECOGFAQ_400  0.899253
# 1     CDR_MultiC_AllFeatures_400     CDR_MultiC_BorutaSHAP_400  0.899253
# 2     CDR_MultiC_AllFeatures_400      CDR_UMCN_AllFeatures_400  0.899253
# 3     CDR_MultiC_AllFeatures_400          CDR_UMCN_Boruta4_400  0.899253
# 4     CDR_MultiC_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.899253
# 5     CDR_MultiC_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.899253
# 6   CDR_MultiC_BorutaECOGFAQ_400     CDR_MultiC_BorutaSHAP_400  0.893528
# 7   CDR_MultiC_BorutaECOGFAQ_400      CDR_UMCN_AllFeatures_400  0.893528
# 8   CDR_MultiC_BorutaECOGFAQ_400          CDR_UMCN_Boruta4_400  0.893528
# 9   CDR_MultiC_BorutaECOGFAQ_400    CDR_UMCN_BorutaECOGFAQ_400  0.893528
# 10  CDR_MultiC_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.893528
# 11     CDR_MultiC_BorutaSHAP_400      CDR_UMCN_AllFeatures_400  0.896861
# 12     CDR_MultiC_BorutaSHAP_400          CDR_UMCN_Boruta4_400  0.896861
# 13     CDR_MultiC_BorutaSHAP_400    CDR_UMCN_BorutaECOGFAQ_400  0.896861
# 14     CDR_MultiC_BorutaSHAP_400       CDR_UMCN_BorutaSHAP_400  0.896861
# 15      CDR_UMCN_AllFeatures_400          CDR_UMCN_Boruta4_400  0.897351
# 16      CDR_UMCN_AllFeatures_400    CDR_UMCN_BorutaECOGFAQ_400  0.897351
# 17      CDR_UMCN_AllFeatures_400       CDR_UMCN_BorutaSHAP_400  0.897351
# 18          CDR_UMCN_Boruta4_400    CDR_UMCN_BorutaECOGFAQ_400  0.893863
# 19          CDR_UMCN_Boruta4_400       CDR_UMCN_BorutaSHAP_400  0.893863
# 20    CDR_UMCN_BorutaECOGFAQ_400       CDR_UMCN_BorutaSHAP_400  0.885637
#
#      mean(B)      diff        se       tail          T   p-tukey    hedges
# 0   0.893528  0.005725  0.001126  two-sided   5.085415  0.001000  0.359255
# 1   0.896861  0.002392  0.001126  two-sided   2.124843  0.338038  0.150108
# 2   0.897351  0.001902  0.001126  two-sided   1.689769  0.499998  0.119372
# 3   0.893863  0.005390  0.001126  two-sided   4.788282  0.001000  0.338264
# 4   0.885637  0.013616  0.001126  two-sided  12.095707  0.001000  0.854492
# 5   0.892546  0.006707  0.001126  two-sided   5.958013  0.001000  0.420899
# 6   0.896861 -0.003333  0.001126  two-sided  -2.960572  0.654246 -0.209147
# 7   0.897351 -0.003822  0.001126  two-sided  -3.395646  0.654246 -0.239883
# 8   0.893863 -0.000334  0.001126  two-sided  -0.297133  0.900000 -0.020991
# 9   0.885637  0.007891  0.001126  two-sided   7.010292  0.001000  0.495236
# 10  0.892546  0.000982  0.001126  two-sided   0.872598  0.900000  0.061644
# 11  0.897351 -0.000490  0.001126  two-sided  -0.435074  0.900000 -0.030735
# 12  0.893863  0.002998  0.001126  two-sided   2.663439  0.654246  0.188156
# 13  0.885637  0.011224  0.001126  two-sided   9.970864  0.001000  0.704384
# 14  0.892546  0.004315  0.001126  two-sided   3.833170  0.654246  0.270791
# 15  0.893863  0.003488  0.001126  two-sided   3.098513  0.654246  0.218892
# 16  0.885637  0.011714  0.001126  two-sided  10.405938  0.001000  0.735119
# 17  0.892546  0.004805  0.001126  two-sided   4.268244  0.001000  0.301527
# 18  0.885637  0.008226  0.001126  two-sided   7.307425  0.001000  0.516227
# 19  0.892546  0.001317  0.001126  two-sided   1.169732  0.900000  0.082635
# 20  0.892546 -0.006909  0.001126  two-sided  -6.137694  0.001000 -0.433592
